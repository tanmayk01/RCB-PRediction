# %%
#necessary imports
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#reading the data
data=pd.read_csv('t20_matches.csv')

pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
data
df=data.copy()

# %%
df.describe()
# Out:
#            match_id     series_id  win_by_runs  win_by_wickets  balls_remaining  innings1_runs  innings1_wickets  innings1_overs_batted  innings1_overs  innings2_runs  innings2_wickets  innings2_overs_batted  innings2_overs  D/L_method      target
# count  6.417000e+03  6.417000e+03  2931.000000     3004.000000      2969.000000    6151.000000       6151.000000            6151.000000     6151.000000    6070.000000       6070.000000            6070.000000     6070.000000       233.0  231.000000
# mean   6.000441e+05  5.879816e+05    31.320710        6.089214        13.978107     151.409527          6.577630              19.523199       19.738612     136.125371          5.998847              17.862537       19.530659         1.0  102.528139
# std    2.302316e+05  2.387841e+05    26.838237        1.996341        14.664918      32.986924          2.152355               1.924720        1.510632      31.880776          2.923842               3.075877        2.108147         0.0   40.406713
# min    1.295970e+05  1.241210e+05     1.000000        1.000000         0.000000       1.000000          0.000000               0.200000        5.000000       0.000000          0.000000               0.100000        5.000000         1.0   20.000000
# 25%    4.249410e+05  4.200050e+05    11.000000        5.000000         4.000000     131.000000          5.000000              20.000000       20.000000     117.000000          4.000000              17.200000       20.000000         1.0   72.000000
# 50%    5.673530e+05  5.642800e+05    24.000000        6.000000         9.000000     152.000000          7.000000              20.000000       20.000000     138.000000          6.000000              19.100000       20.000000         1.0   98.000000
# 75%    7.760790e+05  7.754450e+05    45.000000        8.000000        19.000000     173.000000          8.000000              20.000000       20.000000     157.000000          9.000000              20.000000       20.000000         1.0  129.000000
# max    1.085496e+06  1.083439e+06   172.000000       10.000000       100.000000     263.000000         10.000000              20.000000       20.000000     248.000000         10.000000              20.000000       20.000000         1.0  233.000000

# %%
df1=df[df['match_details'].str.contains('Royal Challengers Bangalore')] ##filter matching of RCB

# %%
df1
# Out:
#       match_id  series_id                                      match_details                                             result                                             scores        date               venue        round                         home                         away                       winner  win_by_runs  win_by_wickets  balls_remaining                     innings1  innings1_runs  innings1_wickets  innings1_overs_batted  innings1_overs                     innings2  innings2_runs  innings2_wickets  innings2_overs_batted  innings2_overs  D/L_method  target
# 897     335982     313494  1st match:Royal Challengers Bangalore v Kolkat...              Kolkata Knight Riders won by 140 runs  Kolkata Knight Riders 222/3 (20/20 ov); Royal ...  18/04/2008           Bangalore    1st match  Royal Challengers Bangalore        Kolkata Knight Riders        Kolkata Knight Riders        140.0             NaN              NaN        Kolkata Knight Riders          222.0               3.0                   20.0            20.0  Royal Challengers Bangalore           82.0              10.0                   15.1            20.0         NaN     NaN
# 901     335985     313494  5th match:Mumbai Indians v Royal Challengers B...  Royal Challengers Bangalore won by 5 wickets (...  Mumbai Indians 165/6 (20/20 ov); Royal Challen...  20/04/2008              Mumbai    5th match               Mumbai Indians  Royal Challengers Bangalore  Royal Challengers Bangalore          NaN             5.0              2.0               Mumbai Indians          165.0               6.0                   20.0            20.0  Royal Challengers Bangalore          166.0               5.0                   19.4            20.0         NaN     NaN
# 908     335992     313494  12th match:Royal Challengers Bangalore v Rajas...  Rajasthan Royals won by 7 wickets (with 17 bal...  Royal Challengers Bangalore 135/8 (20/20 ov); ...  26/04/2008           Bangalore   12th match  Royal Challengers Bangalore             Rajasthan Royals             Rajasthan Royals          NaN             7.0             17.0  Royal Challengers Bangalore          135.0               8.0                   20.0            20.
# std    2.005463e+05  1.981107e+05    0.0    0.501508    35.356869        1.870679        12.178115      33.294162          2.332589               1.847974        1.807632      32.468843          2.807946               2.951182        2.019471         0.0   58.278069
# min    3.359820e+05  3.134940e+05    0.0    0.000000     1.000000        2.000000         0.000000      70.000000          1.000000               8.000000        8.000000       2.000000          0.000000               1.100000        6.000000         1.0   81.000000
# 25%    4.191280e+05  4.180640e+05    0.0    0.000000    14.250000        5.000000         3.000000     142.000000          4.000000              20.000000       20.000000     132.000000          3.000000              17.625000       20.000000         1.0   96.750000
# 50%    5.483100e+05  5.209320e+05    0.0    0.000000    28.500000        6.000000         7.000000     166.000000          6.000000              20.000000       20.000000     150.500000          5.000000              19.200000       20.000000         1.0  139.000000
# 75%    7.339910e+05  6.958710e+05    0.0    1.000000    51.750000        8.000000        12.250000     185.500000          8.000000              20.000000       20.000000     171.000000          8.000000              20.000000       20.000000         1.0  182.750000
# max    1.082591e+06  1.078425e+06    0.0    1.000000   144.000000       10.000000        57.000000     263.000000         10.000000              20.000000       20.000000     215.000000         10.000000              20.000000       20.000000         1.0  203.000000

# %%
df.shape
# Out:
# (6417, 26)

# %%
df1['winner']=np.where(df1['winner']=='Royal Challengers Bangalore',1,0)
# Out:
# C:\Users\tanma\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py:1115: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# C:\Users\tanma\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df1['home']=np.where(df1['home']=='Bangalore',1,0)
# Out:
# C:\Users\tanma\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df1['round'].value_counts()
# Out:
# 5th match              5
# 14th match             5
# 46th match             5
# 11th match             4
# 50th match             4
#                       ..
# 9th match              1
# 13th match             1
# Eliminator             1
# 70th match             1
# 15th Match, Group B    1
# Name: round, Length: 79, dtype: int64

# %%
df1['qualifiers']=np.where(df1['round'].str.contains('Final' and 'Qualifier'),1,0)
# Out:
# C:\Users\tanma\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
lg=df1[df1['qualifiers']==0] ##checking only league matches

# %%
lg['round'].value_counts()
# Out:
# 5th match              5
# 14th match             5
# 46th match             5
# 11th match             4
# 50th match             4
#                       ..
# 9th match              1
# 13th match             1
# Eliminator             1
# 70th match             1
# 15th Match, Group B    1
# Name: round, Length: 77, dtype: int64

# %%
lg.drop(['match_id','series_id','match_details','result','scores','date','round','away'],axis=1,inplace=True)
# Out:
# C:\Users\tanma\Anaconda3\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
lg.isnull().sum()
# Out:
# match_id                   0
# series_id                  0
# match_details              0
# result                     0
# scores                     2
# date                       0
# venue                      0
# round                      0
# home                       0
# away                       0
# winner                     0
# win_by_runs               89
# win_by_wickets            72
# balls_remaining           81
# innings1                   2
# innings1_runs              2
# innings1_wickets           2
# innings1_overs_batted      2
# innings1_overs             2
# innings2                   3
# innings2_runs              3
# innings2_wickets           3
# innings2_overs_batted      3
# innings2_overs             3
# D/L_method               151
# target                   151
# qualifiers                 0
# dtype: int64

# %%
lg.fillna(0,inplace=True)
# Out:
# C:\Users\tanma\Anaconda3\lib\site-packages\pandas\core\frame.py:4244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   **kwargs

# %%
lg.isnull().sum()
# Out:
# match_id                 0
# series_id                0
# match_details            0
# result                   0
# scores                   0
# date                     0
# venue                    0
# round                    0
# home                     0
# away                     0
# winner                   0
# win_by_runs              0
# win_by_wickets           0
# balls_remaining          0
# innings1                 0
# innings1_runs            0
# innings1_wickets         0
# innings1_overs_batted    0
# innings1_overs           0
# innings2                 0
# innings2_runs            0
# innings2_wickets         0
# innings2_overs_batted    0
# innings2_overs           0
# D/L_method               0
# target                   0
# qualifiers               0
# dtype: int64

# %%
lg['D/L_method'].value_counts()
# Out:
# 0.0    151
# 1.0      4
# Name: D/L_method, dtype: int64

# %%
lg
# Out:
#       match_id  series_id                                      match_details                                             result                                             scores        date               venue       round  home                         away  winner  win_by_runs  win_by_wickets  balls_remaining                     innings1  innings1_runs  innings1_wickets  innings1_overs_batted  innings1_overs                     innings2  innings2_runs  innings2_wickets  innings2_overs_batted  innings2_overs  D/L_method  target  qualifiers
#
...     ...          ...             ...              ...                          ...            ...               ...                    ...             ...                    ...            ...               ...                    ...             ...         ...     ...         ...
# 5870    980959     968923  30th match:Royal Challengers Bangalore v Kolka...  Kolkata Knight Riders won by 5 wickets (with 5...  Royal Challengers Bangalore 185/7 (20/20 ov); ...  02/05/2016  Bangalore  30th match     0        Kolkata Knight Riders       0          0.0             5.0              5.0  Royal Challengers Bangalore          185.0               7.0                   20.0            20.0  Kolkata Knight Riders          189.0               5.0                   19.1            20.0         0.0     0.0           0
# 5879    980977     968923  39th match:Kings XI Punjab v Royal Challengers...           Royal Challengers Bangalore won by 1 run  Royal Challengers Bangalore 175/6 (20/20 ov); ...  09/05/2016     Mohali  39th match     0  Royal Challengers Bangalore       0          1.0             0.0              0.0  Royal Challengers Bangalore          175.0               6.0                   20.0            20.0        Kings XI Punjab          174.0               4.0                   20.0            20.0         0.0     0.0           0
# 5881    980981     968923  41st match:Royal Challengers Bangalore v Mumba...  Mumbai Indians won by 6 wickets (with 8 balls ...  Royal Challengers Bangalore 151/4 (20/20 ov); ...  11/05/2016  Bangalore  41st match     0               Mumbai Indians       0          0.0             6.0              8.0  Royal Challengers Bangalore          151.0               4.0                   20.0            20.0         Mumbai Indians          153.0               4.0                   18.4            20.0         0.0     0.0           0
# 5884    980987     968923  44th match:Royal Challengers Bangalore v Gujar...        Royal Challengers Bangalore won by 144 runs  Royal Challengers Bangalore 248/3 (20/20 ov); ...  14/05/2016  Bangalore  44th match     0                Gujarat Lions       0        144.0             0.0              0.0  Royal Challengers Bangalore          248.0               3.0                   20.0            20.0          Gujarat Lions          104.0              10.0                   18.4            20.0         0.0     0.0           0
# 5890    980999     968923  50th match:Royal Challengers Bangalore v Kings...  Royal Challengers Bangalore won by 82 runs (D/...  Royal Challengers Bangalore 211/3 (15/15 ov); ...  18/05/2016  Bangalore  50th match     0              Kings XI Punjab       0         82.0             0.0              0.0  Royal Challengers Bangalore          211.0               3.0                   15.0            15.0        Kings XI Punjab          120.0               9.0                   14.0            14.0         1.0   203.0           0
#
# [68 rows x 27 columns]

# %%
bat_first['winner'].value_counts()
import matplotlib.pyplot as plt
import seaborn as sns

bat_first['winner'].value_counts()
# Out:
# 0    68
# Name: winner, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.barplot(bat_first['winner'].value_counts().index, bat_first['winner'].value_counts().values, alpha=0.8)
plt.title('RCB win or loss batting first')
plt.ylabel('Number of matches', fontsize=12)
plt.xlabel('win or loss', fontsize=12)
plt.show()

# %% [markdown]
# RCB BAtting second

# %%
bat_second=lg[lg['innings2']=='Royal Challengers Bangalore']

# %%
bat_second['winner'].value_counts()
import matplotlib.pyplot as plt
import seaborn as sns

bat_second['winner'].value_counts()
# Out:
# 1    47
# 0    38
# Name: winner, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.barplot(bat_second['winner'].value_counts().index, bat_second['winner'].value_counts().values, alpha=0.8)
plt.title('RCB win or loss batting second')
plt.ylabel('Number of matches', fontsize=12)
plt.xlabel('win or loss', fontsize=12)
plt.show()

# %%
## shows RCB is good at chasing.Obviously considering RCB hass Chase master with em

# %%
## ANalyse by venue

# %%
away=lg[lg['venue']!='Bangalore']
aw=away.groupby(['venue'])['winner']
aw

# %%
away
# Out:
#                    venue  home  winner  win_by_runs  win_by_wickets  balls_remaining                     innings1  innings1_runs  innings1_wickets  innings1_overs_batted  innings1_overs                     innings2  innings2_runs  innings2_wickets  innings2_overs_batted  innings2_overs  D/L_method  target  qualifiers
# 901               Mumbai     0       1          0.0             5.0              2.0               Mumbai Indians          165.0               6.0                   20.0            20.0  Royal Challengers Bangalore          166.0               5.0                   19.4            20.0         0.0     0.0           0
# 913                Delhi     0       0         10.0             0.0              0.0             Delhi Daredevils          191.0               5.0                   20.0            20.0  Royal Challengers Bangalore          181.0               5.0                   20.0            20.0         0.0     0.0           0
# 925              Kolkata     0       0          5.0             0.0              0.0        Kolkata Knight Riders          129.0               7.0                   16.0            16.0  Royal Challengers Bangalore          124.0               4.0                   16.0            16.0         0.0     0.0           0
# 930               Mohali     0       0          0.0             9.0             26.0  Royal Challengers Bangalore          143.0               8.0                   20.0            20.0              Kings XI Punjab          144.0               1.0                   15.4            20.0         0.0     0.0           0
# 935               Jaipur     0       0         65.0             0.0              0.0             Rajasthan Royals          197.0               1.0                   20.0            20.0  Royal Challengers Bangalore          132.0               9.0                   20.0            20.0         0.0     0.0           0
# ...                  ...   ...     ...          ...             ...              ...                          ...            ...               ...                    ...             ...                          ...            ...               ...                    ...             ...         ...     ...         ...
# 5867  Hyderabad (Deccan)     0       0         15.0             0.0              0.0          Sunrisers Hyderabad          194.0               5.0                   20.0            20.0  Royal Challengers Bangalore          179.0               6.0                   20.0            20.0         0.0     0.0           0
# 5879              Mohali     0       1          1.0             0.0              0.0  Royal Challengers Bangalore          175.0               6.0                   20.0            20.0              Kings XI Punjab          174.0               4.0                   20.0            20.0         0.0     0.0           0
# 5888             Kolkata     0       1          0.0             9.0              8.0        Kolkata Knight Riders          183.0               5.0                   20.0            20.0  Royal Challengers Bangalore          186.0               1.0                   18.4            20.0         0.0     0.0           0
# 5896              Raipur     0       1          0.0             6.0             11.0             Delhi Daredevils          138.0               8.0                   20.0            20.0  Royal Challengers Bangalore          139.0               4.0                   18.1            20.0         0.0     0.0           0
# 6413  Hyderabad (Deccan)     0       0         35.0             0.0              0.0          Sunrisers Hyderabad          207.0               4.0                   20.0            20.0  Royal Challengers Bangalore          172.0              10.0                   19.4            20.0         0.0     0.0           0
#
# [89 rows x 19 columns]

# %%
venue=lg['venue']
inn1=lg['innings1']
inn2=lg['innings2']

# %%
inn2.value_counts()
# Out:
# Royal Challengers Bangalore    85
# Kings XI Punjab                12
# Rajasthan Royals                8
# Chennai Super Kings             8
# Mumbai Indians                  8
# Delhi Daredevils                7
# Kolkata Knight Riders           4
# Sunrisers Hyderabad             4
# Pune Warriors                   4
# 0                               3
# Deccan Chargers                 3
# Gujarat Lions                   2
# Warriors                        1
# Victoria                        1
# Rising Pune Supergiants         1
# Somerset                        1
# Cape Cobras                     1
# South Australia                 1
# Otago                           1
# Name: innings2, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
lg['venue']=le.fit_transform(lg.venue)
# Out:
# C:\Users\tanma\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
lg['innings1']=lg.innings1.astype('str')
# Out:
# C:\Users\tanma\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
lg['innings2']=lg.innings2.astype('str')
# Out:
# C:\Users\tanma\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
lg['innings2']=le.fit_transform(lg.innings2)
# Out:
# C:\Users\tanma\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
lg['innings1']=le.fit_transform(lg.innings1)
# Out:
# C:\Users\tanma\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
lg['innings1']
# Out:
# 897      7
# 901      9
# 908     14
# 911      1
# 913      3
#         ..
# 5888     7
# 5890    14
# 5896     3
# 5900    16
# 6413    16
# Name: innings1, Length: 155, dtype: int32

# %%
lg['Winner']=lg['winner']
# Out:
# C:\Users\tanma\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
lg.drop('winner',inplace=True,axis=1)
# Out:
# C:\Users\tanma\Anaconda3\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
lg
# Out:
#       venue  home  win_by_runs  win_by_wickets  balls_remaining  innings1  innings1_runs  innings1_wickets  innings1_overs_batted  innings1_overs  innings2  innings2_runs  innings2_wickets  innings2_overs_batted  innings2_overs  D/L_method  target  qualifi
# 3713      2     0          0.0             7.0             13.0        12          117.0              10.0                   19.4            20.0        13          123.0               3.0                   17.5            20.0         0.0     0.0           0       1
#
# [124 rows x 19 columns]

# %%
c=0
for i in train.columns:
    print(i,'----->',c)
    c=c+1
# Out:
# venue -----> 0
# home -----> 1
# win_by_runs -----> 2
# win_by_wickets -----> 3
# balls_remaining -----> 4
# innings1 -----> 5
# innings1_runs -----> 6
# innings1_wickets -----> 7
# innings1_overs_batted -----> 8
# innings1_overs -----> 9
# innings2 -----> 10
# innings2_runs -----> 11
# innings2_wickets -----> 12
# innings2_overs_batted -----> 13
# innings2_overs -----> 14
# D/L_method -----> 15
# target -----> 16
# qualifiers -----> 17
# Winner -----> 18

# %%
x_tr_bt=train.iloc[:,[0,1,5,10,15]]
y_tr=train.iloc[:,-1]
x_ts_bt=test.iloc[:,[0,1,5,10,15]]
y_ts=test.iloc[:,-1]
x_tr_at=train.iloc[:,[0,1,5,10,15,6,7,8,9,10]]
x_ts_at=test.iloc[:,[0,1,5,10,15,6,7,8,9,10]]

# %%
corr=x_tr_at.corr()

# %%
import seaborn  as sns

# %%
sns.heatmap(corr,annot=True)

# %%
from sklearn.linear_model import LogisticRegression
logr_bt=LogisticRegression()
logr_at=LogisticRegression()

# %%
logr_bt.fit(x_tr_bt,y_tr)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
y_ts.shape
# Out:
# (31,)

# %%
logr_at.fit(x_tr_at,y_tr)
# Out:
# C:\Users\tanma\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression()

# %%
y_pred_at=logr_at.predict(x_ts_at)

# %%
confusion_matrix(y_ts,y_pred_at)
# Out:
# array([[8, 8],
#        [7, 8]], dtype=int64)

# %%
logr_at.fit(x_tr_at,y_tr)
# Out:
# C:\Users\tanma\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression()

# %%
y_pred_at=logr_at.predict(x_ts_at)

# %%
confusion_matrix(y_ts,y_pred_at)
# Out:
# array([[8, 8],
#        [7, 8]], dtype=int64)

# %%
from sklearn.ensemble import RandomForestClassifier
rf_bt=RandomForestClassifier()
rf_at=RandomForestClassifier()

# %%
rf_bt.fit(x_tr_bt,y_tr)
# Out:
# RandomForestClassifier()

# %%
rf_at.fit(x_tr_at,y_tr)
# Out:
# RandomForestClassifier()

# %%
y_pred_at=rf_at.predict(x_ts_at)

# %%
confusion_matrix(y_ts,y_pred_at)
# Out:
# array([[13,  3],
#        [ 2, 13]], dtype=int64)

# %%
from sklearn.ensemble import G
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-65-15006a5dcd87> in <module>
# ----> 1 from sklearn.ensemble import G
#
# ImportError: cannot import name 'G' from 'sklearn.ensemble' (C:\Users\tanma\Anaconda3\lib\site-packages\sklearn\ensemble\__init__.py)

# %%
venue_codes=pd.DataFrame({'venue':venue,'code':lg['venue']})
inn1_codes=pd.DataFrame({'inn1':inn1,'code':lg['innings1']})
inn2_codes=pd.DataFrame({'inn2':inn2,'code':lg['innings2']})

# %%
venue_codes
# Out:
#                    venue  code
# 897            Bangalore     2
# 901               Mumbai    16
# 908            Bangalore     2
# 911            Bangalore     2
# 913                Delhi     6
# ...                  ...   ...
# 5888             Kolkata    14
# 5890           Bangalore     2
# 5896              Raipur    21
# 5900           Bangalore     2
# 6413  Hyderabad (Deccan)    10
#
# [155 rows x 2 columns]

# %%
venue_codes[venue_codes['venue']=='Pune']
# Out:
#      venue  code
# 3030  Pune    20
# 3732  Pune    20
# 5066  Pune    20
# 5856  Pune    20

# %%
inn1_codes
# Out:
#                              inn1  code
# 897         Kolkata Knight Riders     7
# 901                Mumbai Indians     9
# 908   Royal Challengers Bangalore    14
# 911           Chennai Super Kings     1
# 913              Delhi Daredevils     3
# ...                           ...   ...
# 5888        Kolkata Knight Riders     7
# 5890  Royal Challengers Bangalore    14
# 5896             Delhi Daredevils     3
# 5900          Sunrisers Hyderabad    16
# 6413          Sunrisers Hyderabad    16
#
# [155 rows x 2 columns]

# %%
inn2_codes['inn2']
# Out:
# 897     Royal Challengers Bangalore
# 901     Royal Challengers Bangalore
# 908                Rajasthan Royals
# 911     Royal Challengers Bangalore
# 913     Royal Challengers Bangalore
#                    ...
# 5888    Royal Challengers Bangalore
# 5890                Kings XI Punjab
# 5896    Royal Challengers Bangalore
# 5900    Royal Challengers Bangalore
# 6413    Royal Challengers Bangalore
# Name: inn2, Length: 155, dtype: object

# %%
inn2_codes[inn2_codes['inn2']=='Rajasthan Royals']
# Out:
#                   inn2  code
# 908   Rajasthan Royals    11
# 1212  Rajasthan Royals    11
# 1243  Rajasthan Royals    11
# 3003  Rajasthan Royals    11
# 3726  Rajasthan Royals    11
# 4432  Rajasthan Royals    11
# 4453  Rajasthan Royals    11
# 5066  Rajasthan Royals    11

# %%
def find_codes():
    venue1=str(input('Enter venue = '))
    inn1team=str(input('Enter inn1 team= '))
    inn2team=str(input('Enter inn2 team= '))
    for i in venue_codes['venue']:
        if i==venue1:
            print('code for',i,'is= ',venue_codes[venue_codes['venue']==i])
            break
    for k in inn1_codes['inn1']:
        if k==inn1team:
            print('code for',k,'is= ',inn1_codes[inn1_codes['inn1']==k])
            break
    for j in inn2_codes['inn2']:
        if j==inn2team:
            print('code for',j,'is= ',inn2_codes[inn2_codes['inn2']==j])
            break

# %%
inn2_codes[inn2_codes['inn2']=='Rajasthan Royals']
# Out:
#                   inn2  code
# 908   Rajasthan Royals    11
# 1212  Rajasthan Royals    11
# 1243  Rajasthan Royals    11
# 3003  Rajasthan Royals    11
# 3726  Rajasthan Royals    11
# 4432  Rajasthan Royals    11
# 4453  Rajasthan Royals    11
# 5066  Rajasthan Royals    11

# %% [markdown]
# ## Function to find codes for label encoded values

# %%
find_codes()
# Out:
# Enter venue =
# Enter inn1 team=
# Enter inn2 team=

# %% [markdown]
# Function to predict winner with inputs till toss

# %%
def first_inn():
    venue_code=int(input('Enter venue code'))
    is_RCB_home=int(input('is RCB at home? '))
    inn1_team_code=int(input('inn1 team code'))
    inn2_team_code=int(input('inn2 team code'))
    is_DL_method=int(input('is dl method?'))
    x_pars=pd.DataFrame({'1':[venue_code],'2':[is_RCB_home],'3':[inn1_team_code],'4':[inn2_team_code],'5':[is_DL_method]})
    result_before_first_inn=rf_bt.predict(x_pars)
    print(result_before_first_inn)

# %%
find_codes()
# Out:
# Enter venue =
# Enter inn1 team=
# Enter inn2 team=

# %%
c=0
for i in train.columns:
    print(i,'----->',c)
    c=c+1
# Out:
# venue -----> 0
# home -----> 1
# win_by_runs -----> 2
# win_by_wickets -----> 3
# balls_remaining -----> 4
# innings1 -----> 5
# innings1_runs -----> 6
# innings1_wickets -----> 7
# innings1_overs_batted -----> 8
# innings1_overs -----> 9
# innings2 -----> 10
# innings2_runs -----> 11
# innings2_wickets -----> 12
# innings2_overs_batted -----> 13
# innings2_overs -----> 14
# D/L_method -----> 15
# target -----> 16
# qualifiers -----> 17
# Winner -----> 18

# %%
from termcolor import colored

# %% [markdown]
# Deployment

# %% [markdown]
# Function to predict winner with details till end of first innings

# %%
def after_first_inn():
    venue_code=int(input('Enter venue code'))
    is_RCB_home=int(input('is RCB at home? '))
    inn1_team_code=int(input('inn1 team code'))
    inn2_team_code=int(input('inn2 team code'))
    is_DL_method=int(input('is dl method?'))
    innings1_runs=int(input('runs scored by inn1 team '))
    innings1_wickets=int(input('wickets lost by inn1 team '))
    innings1_overs_batted=int(input('overs batted by inn1 team '))
    innings1_overs=int(input('inn1 total allocated overs'))
    innings2=int(input('inn2 team code'))
    x_pars=pd.DataFrame({'1':[venue_code],'2':[is_RCB_home],'3':[inn1_team_code],'4':[inn2_team_code],'5':[is_DL_method],'6':[innings1_runs],'7':[innings1_wickets],'8':[innings1_overs_batted],'9':[innings1_overs],'10':[innings2]})
    result_after_first_inn=logr_at.predict(x_pars)
    probability_of_win=logr_at.predict_proba(x_pars)
    if result_after_first_inn == 1:
        print(colored('RCB will Win','red'))
        print('E Salaa Cup namde Mfs!!!!')
        print(probability_of_win)
    else:
        print('RCB will loose')
        print(probability_of_win)
    print(result_after_first_inn)

# %%
find_codes()
# Out:
# Enter venue = Banglore
# Enter inn1 team= Rajasthan Royals
# Enter inn2 team= Royal Challengers Bangalore
# code for Rajasthan Royals is=                    inn1  code
# 935   Rajasthan Royals    12
# 1704  Rajasthan Royals    12
# 1743  Rajasthan Royals    12
# 2249  Rajasthan Royals    12
# 2991  Rajasthan Royals    12
# 3713  Rajasthan Royals    12
# 5030  Rajasthan Royals    12
# code for Royal Challengers Bangalore is=                               inn2  code
# 897   Royal Challengers Bangalore    13
# 901   Royal Challengers Bangalore    13
# 911   Royal Challengers Bangalore    13
# 913   Royal Challengers Bangalore    13
# 925   Royal Challengers Bangalore    13
# ...                           ...   ...
# 5875  Royal Challengers Bangalore    13
# 5888  Royal Challengers Bangalore    13
# 5896  Royal Challengers Bangalore    13
# 5900  Royal Challengers Bangalore    13
# 6413  Royal Challengers Bangalore    13
#
# [85 rows x 2 columns]

# %%
after_first_inn()
# Out:
# Enter venue code20
# is RCB at home? 0
# inn1 team code11
# inn2 team code13
# is dl method?0
# runs scored by inn1 team 160
# wickets lost by inn1 team 6
# overs batted by inn1 team 20
# inn1 total allocated overs20
# inn2 team code13
# RCB will Win
# E Salaa Cup namde Mfs!!!!
# [[0.43709577 0.56290423]]
# [1]
